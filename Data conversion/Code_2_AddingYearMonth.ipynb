# %%
import os
from osgeo import gdal
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Function to add year and month to CSV
def addYrMntocsv(input_csv, output_csv):
    # Open csv file
    ds = pd.read_csv(input_csv)
    if ds is None:
        print(f"Could not open the csv file: {input_csv}")
        return

    # add new column with year aand month values
    ds['year']=np.ones(len(ds['x']))*int(filename[:4])
    ds['month']=np.ones(len(ds['x']))*int(filename[5:-4])

    # Write DataFrame to CSV
    ds.to_csv(output_csv, index=False)

# Directory containing csv files
input_directory = "Fieschertal\\WindSpeed_Fieschertal_csv\\"

# Output directory for CSV files
output_directory = "Fieschertal\\WindSpeed_Fieschertal_csv1\\"

# Create output directory if it doesn't exist
os.makedirs(output_directory, exist_ok=True)

# Process each csv file
for filename in os.listdir(input_directory):
    if filename.endswith(".csv"):
        input_tiff_path = os.path.join(input_directory, filename)
        output_csv_path = os.path.join(output_directory, filename)
        
        print(f"Adding Year and Month in {input_tiff_path} and output file in {output_csv_path}")
        
        # adding year and month to csv
        addYrMntocsv(input_tiff_path, output_csv_path)
# Out:
# Adding Year and Month in Fieschertal\WindSpeed_Fieschertal_csv\2000_10.csv and output file in Fieschertal\WindSpeed_Fieschertal_csv1\2000_10.csv
# Adding Year and Month in Fieschertal\WindSpeed_Fieschertal_csv\2000_11.csv and output file in Fieschertal\WindSpeed_Fieschertal_csv1\2000_11.csv
# Adding Year and Month in Fieschertal\WindSpeed_Fieschertal_csv\2000_12.csv and output file in Fieschertal\WindSpeed_Fieschertal_csv1\2000_12.csv
# Adding Year and Month in Fieschertal\WindSpeed_Fieschertal_csv\2001_1.csv and output file in Fieschertal\WindSpeed_Fieschertal_csv1\2001_1.csv
# Adding Year and Month in Fieschertal\WindSpeed_Fieschertal_csv\2001_10.csv and output file in Fieschertal\WindSpeed_Fieschertal_csv1\2001_10.csv
# Adding Year and Month in Fieschertal\WindSpeed_Fieschertal_csv\2001_11.csv and output file in Fieschertal\WindSpeed_Fieschertal_csv1\2001_11.csv
# ...
